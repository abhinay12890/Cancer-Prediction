# %%
import numpy as np  
import pandas as pd  
import seaborn as sns

# %%
train=pd.read_csv("C:/Users/david/Desktop/codechef/cancer.csv")
train
# Out:
#       Age   Race Marital Status T Stage N Stage 6th Stage  \
# 0      68  White        Married      T1      N1       IIA
# 1      50  White        Married      T2      N2      IIIA
# 2      58  White       Divorced      T3      N3      IIIC
# 3      58  White        Married      T1      N1       IIA
# 4      47  White        Married      T2      N1       IIB
# ...   ...    ...            ...     ...     ...       ...
# 4019   62  Other        Married      T1      N1       IIA
# 4020   56  White       Divorced      T2      N2      IIIA
# 4021   68  White        Married      T2      N1       IIB
# 4022   58  Black       Divorced      T2      N1       IIB
# 4023   46  White        Married      T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
train.dtypes
# Out:
# Age                        int64
# Race                      object
# Marital Status            object
# T Stage                   object
# N Stage                   object
# 6th Stage                 object
# differentiate             object
# Grade                     object
# A Stage                   object
# Tumor Size                 int64
# Estrogen Status           object
# Progesterone Status       object
# Regional Node Examined     int64
# Reginol Node Positive      int64
# Survival Months            int64
# Status                    object
# dtype: object

# %%
cat=['Race','Marital Status','T Stage','N Stage','6th Stage','differentiate','Grade','A Stage','Estrogen Status','Progesterone Status','Status']

# %%
train
# Out:
#       Age   Race Marital Status T Stage N Stage 6th Stage  \
# 0      68  White        Married      T1      N1       IIA
# 1      50  White        Married      T2      N2      IIIA
# 2      58  White       Divorced      T3      N3      IIIC
# 3      58  White        Married      T1      N1       IIA
# 4      47  White        Married      T2      N1       IIB
# ...   ...    ...            ...     ...     ...       ...
# 4019   62  Other        Married      T1      N1       IIA
# 4020   56  White       Divorced      T2      N2      IIIA
# 4021   68  White        Married      T2      N1       IIB
# 4022   58  Black       Divorced      T2      N1       IIB
# 4023   46  White        Married      T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
for x in cat:
    train[x]=lab.fit_transform(train[x])

# %%
train
# Out:
#       Age  Race  Marital Status  T Stage  N Stage  6th Stage  differentiate  \
# 0      68     2               1        0        0          0              1
# 1      50     2               1        1        1          2              0
# 2      58     2               0        2        2          4              0
# 3      58     2               1        0        0          0              1
# 4      47     2               1        1        0          1              1
# ...   ...   ...             ...      ...      ...        ...            ...
# 4019   62     1               1        0        0          0              0
# 4020   56     2               0        1        1          2              0
# 4021   68     2               1        1        0          1              0
# 4022   58     0               0        1        0          1              0
# 4023   46     2               1        1        0          1              0
#
# ...

# %%
sns.boxplot(x='Age',data=train,whis=[5,95])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(x='Tumor Size',data=train,whis=[5,95])
# Out:
# <AxesSubplot:xlabel='Tumor Size'>

# %%
sns.boxplot(x='Regional Node Examined',data=train,whis=[5,95])
# Out:
# <AxesSubplot:xlabel='Regional Node Examined'>

# %%
sns.boxplot(x='Reginol Node Positive',data=train,whis=[5,95])
# Out:
# <AxesSubplot:xlabel='Reginol Node Positive'>

# %%
sns.boxplot(x='Survival Months',data=train,whis=[5,95])
# Out:
# <AxesSubplot:xlabel='Survival Months'>

# %%
o=['Age','Survival Months','Reginol Node Positive','Regional Node Examined','Tumor Size']
for x in o:
    irq=train[x].quantile(0.75)-train[x].quantile(0.25)
    up=train[x].quantile(0.75)+1.5*irq
    lp=train[x].quantile(0.25)-1.5*irq
    train=train[(train[x]<up) & (train[x]>lp)]
train
# Out:
#       Age  Race  Marital Status  T Stage  N Stage  6th Stage  differentiate  \
# 0      68     2               1        0        0          0              1
# 1      50     2               1        1        1          2              0
# 2      58     2               0        2        2          4              0
# 3      58     2               1        0        0          0              1
# 4      47     2               1        1        0          1              1
# ...   ...   ...             ...      ...      ...        ...            ...
# 4019   62     1               1        0        0          0              0
# 4020   56     2               0        1        1          2              0
# 4021   68     2               1        1        0          1              0
# 4022   58     0               0        1        0          1              0
# 4023   46     2               1        1        0          1              0
#
# ...

# %%
y=train['Status']
x=train.drop('Status',axis="columns")

# %%
x
# Out:
#       Age  Race  Marital Status  T Stage  N Stage  6th Stage  differentiate  \
# 0      68     2               1        0        0          0              1
# 1      50     2               1        1        1          2              0
# 2      58     2               0        2        2          4              0
# 3      58     2               1        0        0          0              1
# 4      47     2               1        1        0          1              1
# ...   ...   ...             ...      ...      ...        ...            ...
# 4019   62     1               1        0        0          0              0
# 4020   56     2               0        1        1          2              0
# 4021   68     2               1        1        0          1              0
# 4022   58     0               0        1        0          1              0
# 4023   46     2               1        1        0          1              0
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.3)

# %%
import statsmodels.api as sm  
es=sm.OLS(y_train,x_train)
e=es.fit()
print(e.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Status   R-squared (uncentered):                   0.286
# Model:                            OLS   Adj. R-squared (uncentered):              0.282
# Method:                 Least Squares   F-statistic:                              61.38
# Date:                Tue, 13 Sep 2022   Prob (F-statistic):                   1.02e-155
# Time:                        21:05:10   Log-Likelihood:                         -491.41
# No. Observations:                2310   AIC:                                      1013.
# Df Residuals:                    2295   BIC:                                      1099.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
train.columns
# Out:
# Index(['Age', 'Race', 'Marital Status', 'T Stage', 'N Stage', '6th Stage',
#        'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status',
#        'Progesterone Status', 'Regional Node Examined',
#        'Reginol Node Positive', 'Survival Months', 'Status'],
#       dtype='object')

# %%
train.drop(['Race','Marital Status','N Stage','6th Stage','differentiate','Tumor Size','Estrogen Status'],axis="columns",inplace=True)

# %%
train
# Out:
#       Age  T Stage  Grade  A Stage  Progesterone Status  \
# 0      68        0      3        1                    1
# 1      50        1      2        1                    1
# 2      58        2      2        1                    1
# 3      58        0      3        1                    1
# 4      47        1      3        1                    1
# ...   ...      ...    ...      ...                  ...
# 4019   62        0      2        1                    1
# 4020   56        1      2        1                    1
# 4021   68        1      2        1                    0
# 4022   58        1      2        1                    1
# 4023   46        1      2        1                    1
#
#       Regional Node Examined  Reginol Node Positive  Survival Months  Status
# 0                         24                      1               60       0
# 1                         14                      5               62       0
# ...

# %%
y=train["Status"]
x=train.drop("Status",axis="columns")

# %%
y.value_counts()
# Out:
# 0    2907
# 1     393
# Name: Status, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

smote=SMOTE(sampling_strategy="minority")
xn,yn=smote.fit_resample(x,y)

yn.value_counts()
# Out:
# 0    2907
# 1    2907
# Name: Status, dtype: int64

# %%
xn
# Out:
#       Age  T Stage  Grade  A Stage  Progesterone Status  \
# 0      68        0      3        1                    1
# 1      50        1      2        1                    1
# 2      58        2      2        1                    1
# 3      58        0      3        1                    1
# 4      47        1      3        1                    1
# ...   ...      ...    ...      ...                  ...
# 5809   57        1      2        1                    1
# 5810   56        1      3        1                    0
# 5811   44        1      2        1                    1
# 5812   60        1      2        1                    0
# 5813   59        1      3        1                    1
#
#       Regional Node Examined  Reginol Node Positive  Survival Months
# 0                         24                      1               60
# 1                         14                      5               62
# 2                         14                      7               75
# ...

# %%
from sklearn.preprocessing import StandardScaler
nor=StandardScaler()
for qw in xn.columns:
    a=np.array(xn[qw]).reshape(-1,1)
    nor.fit(a)
    xn[qw]=nor.transform(a).reshape(-1,1)
xn
# Out:
#            Age   T Stage     Grade  A Stage  Progesterone Status  \
# 0     1.500913 -0.953591  1.542991   0.1693             0.663728
# 1    -0.494787  0.649236 -0.106081   0.1693             0.663728
# 2     0.392191  2.252062 -0.106081   0.1693             0.663728
# 3     0.392191 -0.953591  1.542991   0.1693             0.663728
# 4    -0.827404  0.649236  1.542991   0.1693             0.663728
# ...        ...       ...       ...      ...                  ...
# 5809  0.281319  0.649236 -0.106081   0.1693             0.663728
# 5810  0.170447  0.649236  1.542991   0.1693            -1.506641
# 5811 -1.160020  0.649236 -0.106081   0.1693             0.663728
# 5812  0.613935  0.649236 -0.106081   0.1693            -1.506641
# 5813  0.503063  0.649236  1.542991   0.1693             0.663728
#
#       Regional Node Examined  Reginol Node Positive  Survival Months
# 0                   1.669734              -0.808921        -0.083748
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(xn,yn,random_state=42,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
model.score(x_train,y_train)
# Out:
# 1.0

# %%
rpred=model.predict(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
model.score(x_train,y_train)
# Out:
# 1.0

# %%
tpred=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
print("E Random:",mean_squared_error(y_test,rpred)**0.5)
print("E Tree:",mean_squared_error(y_test,tpred)**0.5)
# Out:
# E Random: 0.3093574077513888
# E Tree: 0.37008478855031635
